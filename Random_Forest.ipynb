# %% [markdown]
# #  Random Forest Classification
# This notebook demonstrates how to build, train, and evaluate a **Random Forest Classifier** using Python. We will go step by step from data preprocessing to model evaluation.

# %% [markdown]
# ##  Step 1: Import Libraries
# We start by importing all the necessary Python libraries for data handling, visualization, and model building.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##  Step 2: Load the Dataset
# We load the dataset and check the first few rows to understand its structure.

# %%
df=pd.read_csv('/content/customer_churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ##  Step 3: Exploratory Data Analysis (EDA)
# Here we explore the dataset, check for missing values, and visualize important features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# ## Step 4: Data Preprocessing
# Before training the model, we prepare the data:
# - Handle missing values
# - Encode categorical variables
# - Split into train and test sets
# - Scale features if necessary

# %%
df.describe(include='O')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     3186-AJIEK   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %% [markdown]
# ##  Step 5: Build Random Forest Model
# We initialize and train a Random Forest Classifier. Random Forest is an **ensemble learning method** that combines multiple decision trees to improve performance and reduce overfitting.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ##  Step 6: Train the Model
# We fit the model on the training dataset.

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Step 7: Evaluate the Model
# We evaluate the trained model using:
# - Accuracy Score
# - Confusion Matrix
# - Classification Report

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
col=[]
for i in df.columns:
  if df[i].dtype=='object':
    col.append(i)

# %%
col
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %% [markdown]
# ## 🔍 Step 8: Hyperparameter Tuning (Optional)
# We can use techniques like **GridSearchCV** or **RandomizedSearchCV** to find the best hyperparameters for Random Forest.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in col:
  df[i]=le.fit_transform(df[i])

# %% [markdown]
# ##  Conclusion
# We successfully built and evaluated a Random Forest Classifier. This approach is powerful for classification problems and works well even with large datasets.

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5365       0              0        1           0       1
# 1        3953       1              0        0           0      34
# 2        2558       1              0        0           0       2
# 3        5524       1              0        0           0      45
# 4        6500       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
x=df.drop(columns = ['Churn'])
y=df['Churn']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_tyest,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from random import Random
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier()
r.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=r.predict(x_tyest)

# %%
from sklearn.metrics import *
accuracy_score(y_test,y_pred)
# Out:
# 0.7909952606635071

# %%
from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
yp=d.predict(x_tyest)
accuracy_score(y_test,yp)
# Out:
# 0.7218009478672985

# %% [markdown]
# So from here we get that Random forest is best suited for this dataset.
